# %%
import pandas as pd
pd.read_csv('Github_data.csv')
# Out:
#       Unnamed: 0.1  Unnamed: 0         topic  \
# 0                0           0  Data-Science
# 1                1           1  Data-Science
# 2                2           2  Data-Science
# 3                3           3  Data-Science
# 4                4           4  Data-Science
# ...            ...         ...           ...
# 1495           295          95        sensor
# 1496           296          96        sensor
# 1497           297          97        sensor
# 1498           298          98        sensor
# 1499           299          99        sensor
#
#                                                    name              user  \
# 0                                                 keras        keras-team
# 1                                          scikit-learn      scikit-learn
# 2                             PythonDataScienceHandbook           jakevdp
# 3     Probabilistic-Programming-and-Bayesian-Methods...  CamDavidsonPilon
# ...
